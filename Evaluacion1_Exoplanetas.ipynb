# %%
import pandas as pd
df = pd.read_csv("planets.csv")
df.head()
# Out:
#    rowid pl_hostname pl_letter    pl_discmethod  pl_pnum  pl_orbper  \
# 0      1      11 Com         b  Radial Velocity        1     326.03
# 1      2      11 UMi         b  Radial Velocity        1     516.22
# 2      3      14 And         b  Radial Velocity        1     185.84
# 3      4      14 Her         b  Radial Velocity        1    1773.40
# 4      5    16 Cyg B         b  Radial Velocity        1     798.50
#
#    pl_orbpererr1  pl_orbpererr2  pl_orbperlim  pl_orbsmax  ...  st_masserr1  \
# 0           0.32          -0.32           0.0       1.290  ...         0.30
# 1           3.25          -3.25           0.0       1.540  ...         0.25
# 2           0.23          -0.23           0.0       0.830  ...         0.10
# 3           2.50          -2.50           0.0       2.770  ...         0.05
# 4           1.00          -1.00           0.0       1.681  ...          NaN
#
#    st_masserr2  st_masslim  st_massblend  st_rad  st_raderr1  st_raderr2  \
# 0        -0.30         0.0           0.0   19.00        2.00       -2.00
# 1        -0.25         0.0           0.0   24.08        1.84       -1.84
# 2        -0.20         0.0           0.0   11.00        1.00       -1.00
# 3        -0.05         0.0           0.0     NaN         NaN         NaN
# 4          NaN         0.0           0.0     NaN         NaN         NaN
#
#    st_radlim  st_radblend   rowupdate
# 0        0.0          0.0  2014-05-14
# 1        0.0          0.0  2014-05-14
# 2        0.0          0.0  2014-05-14
# 3        NaN          0.0  2014-05-14
# 4        NaN          0.0  2015-09-10
#
# [5 rows x 67 columns]

# %%
print("Valores nulos por columna:")
print(df.isnull().sum())
# Out:
# Valores nulos por columna:
# rowid              0
# pl_hostname        0
# pl_letter          0
# pl_discmethod      0
# pl_pnum            0
#                 ...
# st_raderr1       417
# st_raderr2       494
# st_radlim        358
# st_radblend      187
# rowupdate          0
# Length: 67, dtype: int64

# %%
# ...existing code...
# Celda nueva: Limpieza general para planets.csv (nulos, duplicados, outliers, flags)
import re
import numpy as np

# trabajar sobre una copia
df_clean = df.copy()
print("Forma inicial:", df_clean.shape)

# 1) Duplicados
antes = len(df_clean)
df_clean.drop_duplicates(inplace=True)
print("Duplicados eliminados:", antes - len(df_clean))

# 2) Eliminar columnas con muchos nulos (>80%)
pct_nulos = df_clean.isnull().mean()
drop_many = pct_nulos[pct_nulos > 0.80].index.tolist()
print("Columnas >80% nulas (se eliminan):", drop_many)
df_clean.drop(columns=drop_many, inplace=True, errors='ignore')
df_clean.head(5)
# Out:
# Forma inicial: (3372, 67)
# Duplicados eliminados: 0
# Columnas >80% nulas (se eliminan): ['pl_orbincl', 'pl_orbinclerr1', 'pl_orbinclerr2', 'pl_orbincllim', 'pl_dens', 'pl_denserr1', 'pl_denserr2', 'pl_denslim', 'st_optmagerr']
#    rowid pl_hostname pl_letter    pl_discmethod  pl_pnum  pl_orbper  \
# 0      1      11 Com         b  Radial Velocity        1     326.03
# 1      2      11 UMi         b  Radial Velocity        1     516.22
# 2      3      14 And         b  Radial Velocity        1     185.84
# 3      4      14 Her         b  Radial Velocity        1    1773.40
# 4      5    16 Cyg B         b  Radial Velocity        1     798.50
#
#    pl_orbpererr1  pl_orbpererr2  pl_orbperlim  pl_orbsmax  ...  st_masserr1  \
# 0           0.32          -0.32           0.0       1.290  ...         0.30
# 1           3.25          -3.25           0.0       1.540  ...         0.25
# 2           0.23          -0.23           0.0       0.830  ...         0.10
# 3           2.50          -2.50           0.0       2.770  ...         0.05
# 4           1.00          -1.00           0.0       1.681  ...          NaN
#
#    st_masserr2  st_masslim  st_massblend  st_rad  st_raderr1  st_raderr2  \
# 0        -0.30         0.0           0.0   19.00        2.00       -2.00
# 1        -0.25         0.0           0.0   24.08        1.84       -1.84
# 2        -0.20         0.0           0.0   11.00        1.00       -1.00
# 3        -0.05         0.0           0.0     NaN         NaN         NaN
# 4          NaN         0.0           0.0     NaN         NaN         NaN
#
#    st_radlim  st_radblend   rowupdate
# 0        0.0          0.0  2014-05-14
# 1        0.0          0.0  2014-05-14
# 2        0.0          0.0  2014-05-14
# 3        NaN          0.0  2014-05-14
# 4        NaN          0.0  2015-09-10
#
# [5 rows x 58 columns]
